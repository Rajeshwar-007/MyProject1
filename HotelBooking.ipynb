# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("hotel_booking.csv")

# %%
df
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %%
df.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  119390.000000  119390.000000      119390.000000
# mean        0.370416     104.011416        2016.156554
# std         0.482918     106.863097           0.707476
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     160.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             119390.000000              119390.000000
# mean                  27.165173                  15.798241
# std                   13.605138                   8.780829
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %%
df.describe(include = object)
# Out:
#              hotel arrival_date_month    meal country market_segment  \
# count       119390             119390  119390  118902         119390
# unique           2                 12       5     177              8
# top     City Hotel             August      BB     PRT      Online TA
# freq         79330              13877   92310   48590          56477
#
#        distribution_channel reserved_room_type assigned_room_type  \
# count                119390             119390             119390
# unique                    5                 10                 12
# top                   TA/TO                  A                  A
# freq                  97870              85994              74053
#
#        deposit_type customer_type reservation_status reservation_status_date  \
# count        119390        119390             119390                  119390
# unique            3             4                  3                     926
# ...

# %%
df.isnull().sum()
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# ...

# %%
df.drop(["name","email","phone-number","credit_card","company","agent"], axis =  1 , inplace = True)

# %%
df
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 30 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
df["reservation_status_date"]=pd.to_datetime(df["reservation_status_date"])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 30 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
for col in df.describe(include = object).columns:
    print(col)
    print(df[col].unique())
    print("-"*50)
# Out:
# hotel
# ['Resort Hotel' 'City Hotel']
# --------------------------------------------------
# arrival_date_month
# ['July' 'August' 'September' 'October' 'November' 'December' 'January'
#  'February' 'March' 'April' 'May' 'June']
# --------------------------------------------------
# meal
# ['BB' 'FB' 'HB' 'SC' 'Undefined']
# --------------------------------------------------
# country
# ['PRT' 'GBR' 'USA' 'ESP' 'IRL' 'FRA' nan 'ROU' 'NOR' 'OMN' 'ARG' 'POL'
#  'DEU' 'BEL' 'CHE' 'CN' 'GRC' 'ITA' 'NLD' 'DNK' 'RUS' 'SWE' 'AUS' 'EST'
#  'CZE' 'BRA' 'FIN' 'MOZ' 'BWA' 'LUX' 'SVN' 'ALB' 'IND' 'CHN' 'MEX' 'MAR'
#  'UKR' 'SMR' 'LVA' 'PRI' 'SRB' 'CHL' 'AUT' 'BLR' 'LTU' 'TUR' 'ZAF' 'AGO'
#  'ISR' 'CYM' 'ZMB' 'CPV' 'ZWE' 'DZA' 'KOR' 'CRI' 'HUN' 'ARE' 'TUN' 'JAM'
#  'HRV' 'HKG' 'IRN' 'GEO' 'AND' 'GIB' 'URY' 'JEY' 'CAF' 'CYP' 'COL' 'GGY'
#  'KWT' 'NGA' 'MDV' 'VEN' 'SVK' 'FJI' 'KAZ' 'PAK' 'IDN' 'LBN' 'PHL' 'SEN'
#  'SYC' 'AZE' 'BHR' 'NZL' 'THA' 'DOM' 'MKD' 'MYS' 'ARM' 'JPN' 'LKA' 'CUB'
# ...

# %%
cancel_perc = df["is_canceled"].value_counts(normalize = True)

# %%
cancel_perc
# Out:
# is_canceled
# 0    0.629584
# 1    0.370416
# Name: proportion, dtype: float64

# %%
plt.figure(figsize=(4,6))
plt.title("Reservation Status")
plt.bar(["Not Canceled","Canceled"],df["is_canceled"].value_counts(),edgecolor = "Black")
plt.show()

# %% [markdown]
# ## The above bar graph shows percentage of reservation that are  not canceled and canceled . There are more no. of not canceled reservation. There are still 37% of clients who canceled their reservation, which has a significant impact on the hotels earnings.

# %%
plt.figure(figsize=(8,4))
hb = sns.countplot(x= "hotel",hue = "is_canceled",data = df)
plt.legend(["Not Canceled" , "Canceled"])
plt.xlabel("Hotels")
plt.ylabel("Number of Reservation ")
plt.title("Reservation in different hotels")
plt.show()

# %% [markdown]
# ### The above Comaparison is between Resort hotel and City hotel.It can show that City hotel have more booking than Resort hotel .It's possible that City hotel have less expensive than Resort hotel.

# %%
resort_hotel = df[df["hotel"] == "Resort Hotel"]
resort_hotel['is_canceled'].value_counts(normalize = True)
# Out:
# is_canceled
# 0    0.722366
# 1    0.277634
# Name: proportion, dtype: float64

# %%
city_hotel = df[df["hotel"] == "City Hotel"]
city_hotel["is_canceled"].value_counts(normalize = True)
# Out:
# is_canceled
# 0    0.58273
# 1    0.41727
# Name: proportion, dtype: float64

# %%
resort_hotel = resort_hotel.groupby("reservation_status_date")[["adr"]].mean()
city_hotel = city_hotel.groupby("reservation_status_date")[["adr"]].mean()

# %%
plt.figure(figsize=(20,8))
plt.title("Average daily rate in city and resort hotel",fontsize = 20 )
plt.plot(resort_hotel.index , resort_hotel['adr'],label="Resort Hotel")
plt.plot(city_hotel.index , city_hotel['adr'],label="City Hotel")
plt.legend()
plt.show()

# %% [markdown]
# ### The above line tells the Average daily rate of City hotel is more consistent than Resort hotel.

# %%
df["month"] = df["reservation_status_date"].dt.month
ax = sns.countplot(x = "month", hue = "is_canceled",data =df)
plt.title("Reservation status per month ")
plt.xlabel("month")
plt.ylabel("number of reservation")
plt.legend(["Not Canceled","canceled"])
plt.show()

# %%
plt.figure(figsize= (15,4))
plt.title("ADR per month ")
sns.barplot(x = "month",y = "adr",data = df[df["is_canceled"] == 1].groupby("month")[["adr"]].sum().reset_index() )
plt.show()

# %% [markdown]
# ### The above two bar graph shows reservation and ADR per month respectivily.In January , the cancellation rate is high because of ADR is high in january .Therefore ,the ADR affects on the reservation of hotels.

# %%
canceled_date = df[df["is_canceled"] == 1]
top_10_country = canceled_date["country"].value_counts()[ :10]
plt.figure(figsize= (8,8))
plt.title("Top 10 Countries with reservation canceled")
plt.pie(top_10_country, autopct = "%.2f" ,labels = top_10_country.index)
plt.show()

# %% [markdown]
# ### Now, let's see which country has the highest reservation canceled. The top country is Portugal with the highest number of cancellations.

# %%
df["market_segment"].value_counts()
# Out:
# market_segment
# Online TA        56477
# Offline TA/TO    24219
# Groups           19811
# Direct           12606
# Corporate         5295
# Complementary      743
# Aviation           237
# Undefined            2
# Name: count, dtype: int64

# %%
df["market_segment"].value_counts(normalize = True)
# Out:
# market_segment
# Online TA        0.473046
# Offline TA/TO    0.202856
# Groups           0.165935
# Direct           0.105587
# Corporate        0.044350
# Complementary    0.006223
# Aviation         0.001985
# Undefined        0.000017
# Name: proportion, dtype: float64

# %%
canceled_date["market_segment"].value_counts(normalize = True)
# Out:
# market_segment
# Online TA        0.468954
# Groups           0.273539
# Offline TA/TO    0.187930
# Direct           0.043732
# Corporate        0.022431
# Complementary    0.002193
# Aviation         0.001176
# Undefined        0.000045
# Name: proportion, dtype: float64

# %% [markdown]
# ### Let's check the area from where guests are visiting the hotels and making reservations.Is it coming from Direct or Groups, Online or Offline Travel Agents? Around 46% of the clients come from online travel agencies, whereas 27% come from groups. Only 4% of clients book hotels directly by visiting them and making reservations.

# %%
canceled_date = df[df["is_canceled"] == 1]
canceled_adr = canceled_date.groupby("reservation_status_date")[["adr"]].mean()
canceled_adr.reset_index(inplace = True)
canceled_adr.sort_values("reservation_status_date", inplace = True)

not_canceled_date = df[df["is_canceled"] == 0]
not_canceled_adr =not_canceled_date.groupby("reservation_status_date")[["adr"]].mean()
not_canceled_adr.reset_index(inplace = True)
not_canceled_adr.sort_values("reservation_status_date", inplace = True)

plt.figure(figsize =(20,4))
plt.title("Averge Daily Rate")
plt.plot(not_canceled_adr["reservation_status_date"],not_canceled_adr["adr"],label = "not canceled")    
plt.plot(canceled_adr["reservation_status_date"],canceled_adr["adr"],label = "canceled")           
plt.legend()         
plt.show()

# %%
canceled_adr = canceled_adr[(canceled_adr["reservation_status_date"] > "2015-09") & (canceled_adr["reservation_status_date"] < "2017-09")]
not_canceled_adr = not_canceled_adr[(not_canceled_adr["reservation_status_date"] > "2015-09") & (not_canceled_adr["reservation_status_date"] < "2017-09")]

# %%
plt.figure(figsize =(20,4))
plt.title("Averge Daily Rate")
plt.plot(not_canceled_adr["reservation_status_date"],not_canceled_adr["adr"],label = "not canceled")    
plt.plot(canceled_adr["reservation_status_date"],canceled_adr["adr"],label = "canceled")           
plt.legend()  
plt.show()

# %% [markdown]
# ### As seen in the graph, reservations are canceled when the average daily rate is higher . It clearly proves all the above analysis, that the higher price leads to higher cancellation.
